# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def mean_squared_error(y , yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2 ) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)

print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 168.784

# %% [markdown]
# 作業1：
# Freesound Audio Tagging 2019
# https://www.kaggle.com/c/freesound-audio-tagging-2019
#
# 1. 你選的這組資料為何重要
# 說到ML最大的挑戰，就是要如何產生大量且有效的資料集，目前大多數有效資料都是經過人工標記，這會造成巨大的時間成本，無法產生足夠大的資料集，這次比賽是以聲音為主，有些聲音非常的易於辨識，很容易聽出來是什麼樣的聲音，比如說是吉他的演奏聲、小孩的嬉鬧聲、湯匙敲打碗盤的聲音，但有許多狀況下，音源發生的周圍環境非常的嘈雜，或是混合許多不同性質的聲音，這會造成利用自動辨識系統，來製作聲音標籤的挑戰性更為艱難，所以此次的比賽就是集思廣益來找出什麼樣的模型最有效率。
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 此資料集為Freesound Dataset，從MTG(Music Technology Group)收集而來。另一個為Yahoo Flickr Creative Commons 100M數據集（YFCC）的Flickr配樂池的音樂。
# 3. 蒐集而來的資料型態為何
# 資料型態有wav（音訊）、csv（表格）。
# 4. 這組資料想解決的問題如何評估
# 透過正確率來驗證模型是否正確，資料庫內有手動標記的資料，以此資料為基準來判斷訓練的模型是否有效。
#
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 載客通常會牽涉司機與乘客兩方的因果變化，所以必須分開提問兩方會產生的行為-
# 司機登記時的車況如何？司機的年齡與背景如何？有提供什麼樣的金流模式（刷卡、現金、優惠卷）？
# 乘客上車地與到達地為何？乘客使用的付款方式為何？乘客對司機的評價為何？司機是否有繞路或是不良行為？
# 重點在於提升載客產生的現金流，如何使司機單趟的成本與利潤達到最高。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 假設以手機應用程式與客服叫車，手機設計一些可以回饋司機評價的機制，如乘車星數，是否有幫乘客提行李、是否態度禮貌、是否準時。
# 透過這些數據建立表單或是動態的數據資料庫。
# 3. 蒐集而來的資料型態為何
# 收集的資料會以文字表格為主，建立出資料庫來分析資料的影響力。
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 可以利用GA系統結合觀察手機的流量，標準為公司單位時間收到的金額為標的，來觀察業績是否有提升，設計季度、月度、每週的時間分別，並依照客戶回饋淘汰不適任的司機。
